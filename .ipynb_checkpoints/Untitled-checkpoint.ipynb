# %%
import my_submission as ms
import function_tester as ft

# %%
ft.fmodel(1,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-ca6a2a862f00> in <module>()
# ----> 1 ft.fmodel(1,2)
#
# ~/Google Drive/Skolan/Brisbane/IFN680 - Advanced Topics in Artificial Intelligence/Assignments/#1/IFN680_Assignment1/function_tester.py in fmodel(x, w)
#      16         '''DONE - INSERT MISSING CODE HERE'''
#      17         # Following 2 lines inserted by Max
# ---> 18         for i in range(0,len(w)):
#      19             y = w[i] * (x**i)
#      20
#
# TypeError: object of type 'int' has no len()

# %%
ms.task_1()
